# %%
import joblib

model=joblib.load('KNN_model.sav')

# %%
#test_data=[[0.4,2.1,5.1,2.2],
#       [2.1,5.5,2.1,1.1]]

test = [[0.9,2.3,4.2,5.8]]
result=model.predict(test)
print(result)
# Out:
# [2.]
